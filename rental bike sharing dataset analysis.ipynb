# %% [markdown]
# # **REG NO : 2017331026**
# # **Name : MD FAHIMUL ISLAM**

# %% [markdown]
# # **TASK 1:**

# %% [markdown]
# **1. Describe what a Data Frame is**

# %% [markdown]
# ### **DATA FRAME:**  Data frame is a kind of data structure that orgamizes data into a two dimensional table of rows and columns where each column contains values of one variable and each row contains one set of values from each column. Some characteristics of Data Frame are:
# 1) Row names should be unique.
# 2) Column name should be non-empty.

# %% [markdown]
# **2. Open/Load the csv file into a Data Frame.**

# %%
import seaborn as sb
import pandas as pd
from scipy.stats import norm
import matplotlib.pyplot as plt
import numpy as np
import statistics as stat
from matplotlib.pyplot import figure
import warnings
# %matplotlib inline
warnings.filterwarnings('ignore')

from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-0daa04f2-2cc5-46f4-8a2c-2e7bbda8fce2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0daa04f2-2cc5-46f4-8a2c-2e7bbda8fce2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving day.csv to day (1).csv

# %%
hour = pd.read_csv('hour.csv')
# day = pd.DataFrame(day)
hour.head()
# Out:
#    instant      dteday  season  yr  ...  windspeed  casual  registered  cnt
# 0        1  2011-01-01       1   0  ...        0.0       3          13   16
# 1        2  2011-01-01       1   0  ...        0.0       8          32   40
# 2        3  2011-01-01       1   0  ...        0.0       5          27   32
# 3        4  2011-01-01       1   0  ...        0.0       3          10   13
# 4        5  2011-01-01       1   0  ...        0.0       0           1    1
#
# [5 rows x 17 columns]

# %% [markdown]
# **3. Get the size of the data table.**

# %%
size_day = hour.size
print(size_day)
# Out:
# 295443

# %% [markdown]
# **3. Get the column names.**

# %%
list(hour.columns.values)
# Out:
# ['instant',
#  'dteday',
#  'season',
#  'yr',
#  'mnth',
#  'hr',
#  'holiday',
#  'weekday',
#  'workingday',
#  'weathersit',
#  'temp',
#  'atemp',
#  'hum',
#  'windspeed',
#  'casual',
#  'registered',
#  'cnt']

# %% [markdown]
# **5. Get the data types of the columns.**

# %%
day.dtypes
# Out:
# instant         int64
# dteday         object
# season          int64
# yr              int64
# mnth            int64
# hr              int64
# holiday         int64
# weekday         int64
# workingday      int64
# weathersit      int64
# temp          float64
# atemp         float64
# hum           float64
# windspeed     float64
# casual          int64
# registered      int64
# cnt             int64
# dtype: object

# %% [markdown]
# **6. Find if there are any null/missing values. (See isna(), isnull(), notna() etc.)**

# %%
day.isnull().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %% [markdown]
# **7. Drop if there is any duplicate rows, or missing values. (See dropna(), drop_duplicates() etc.)**

# %%
day.dropna()
day.size
# Out:
# 295443

# %%
isDuplicates = day.duplicated().sum()
print(isDuplicates)
day.drop_duplicates(keep=False)
print(day.size)
# Out:
# 0
# 295443

# %% [markdown]
# **day.fillna(day.mean()) :** this is used to replace al null values with the mean values of that column of the null value.

# %% [markdown]
# **8. Replace the null values with average/0/min/max values etc. (See fillna(), ffill(), bfill() etc.)**

# %%
day.fillna(day.mean())

day.fillna(day.max())

day.fillna(day.min())

day.fillna(0)
# Out:
#        instant      dteday  season  yr  ...  windspeed  casual  registered  cnt
# 0            1  2011-01-01       1   0  ...     0.0000       3          13   16
# 1            2  2011-01-01       1   0  ...     0.0000       8          32   40
# 2            3  2011-01-01       1   0  ...     0.0000       5          27   32
# 3            4  2011-01-01       1   0  ...     0.0000       3          10   13
# 4            5  2011-01-01       1   0  ...     0.0000       0           1    1
# ...        ...         ...     ...  ..  ...        ...     ...         ...  ...
# 17374    17375  2012-12-31       1   1  ...     0.1642      11         108  119
# 17375    17376  2012-12-31       1   1  ...     0.1642       8          81   89
# 17376    17377  2012-12-31       1   1  ...     0.1642       7          83   90
# 17377    17378  2012-12-31       1   1  ...     0.1343      13          48   61
# 17378    17379  2012-12-31       1   1  ...     0.1343      12          37   49
#
# ...

# %% [markdown]
# **9. Get data only from a particular column**

# %%
day.yr
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 17374    1
# 17375    1
# 17376    1
# 17377    1
# 17378    1
# Name: yr, Length: 17379, dtype: int64

# %% [markdown]
# **10. Count different column values.**

# %%
day.describe()
# Out:
#           instant        season  ...    registered           cnt
# count  17379.0000  17379.000000  ...  17379.000000  17379.000000
# mean    8690.0000      2.501640  ...    153.786869    189.463088
# std     5017.0295      1.106918  ...    151.357286    181.387599
# min        1.0000      1.000000  ...      0.000000      1.000000
# 25%     4345.5000      2.000000  ...     34.000000     40.000000
# 50%     8690.0000      3.000000  ...    115.000000    142.000000
# 75%    13034.5000      3.000000  ...    220.000000    281.000000
# max    17379.0000      4.000000  ...    886.000000    977.000000
#
# [8 rows x 16 columns]

# %% [markdown]
# Here we can see that minimum number of bike rent is 22 and maximum is 8714.Average of those bike rent is 4504.

# %% [markdown]
# ## **TASK 2**

# %% [markdown]
# **1. Explain the contents of the dataset.**

# %% [markdown]
# This dataset contains number of rental bikes between 2011 and 2012 in capital bikeshare system on an hourly basis which also corresponds to weather,seasonal and weekday informations.This dataset has 10886 rows and 12 columns where season,working day,weekend columns are categorical and rests are numerical except dteday column.Our purpose is to build learning model to predict the count of active users of rental bikes.
#
# - instant: record index
# - dteday : date
# - season : season (1:spring, 2:summer, 3:fall, 4:winter)
# - yr : year (0: 2011, 1:2012)
# - mnth : month ( 1 to 12)
# - hr : hour (0 to 23)
# - holiday : weather day is holiday or not
# - weekday : day of the week
# - workingday : if day is neither weekend nor holiday is 1, otherwise is 0.
# - weathersit :
#   - 1: Clear, Few clouds, Partly cloudy, Partly cloudy
#   - 2: Mist + Cloudy, Mist + Broken clouds, Mist + Few clouds, Mist
#   - 3: Light Snow, Light Rain + Thunderstorm + Scattered clouds, Light Rain + Scattered clouds
#   - 4: Heavy Rain + Ice Pallets + Thunderstorm + Mist, Snow + Fog
# - temp : Normalized temperature in Celsius. The values are divided to 41 (max)
# - atemp: Normalized feeling temperature in Celsius. The values are divided to 50 (max)
# - hum: Normalized humidity. The values are divided to 100 (max)
# - windspeed: Normalized wind speed. The values are divided to 67 (max)
# - casual: count of casual users
# - registered: count of registered users
# - cnt: count of total rental bikes including both casual and registered

# %% [markdown]
# **2. Plot various aspects of the features like distribution, range of values correlation with others to see the trend in data, different categories etc.**
#
# *and*
#
# **3. Interpret those visualizations.**

# %%
hour = day
hour = hour.rename(columns={'weathersit':'weather',
                       'yr':'year',
                       'mnth':'month',
                       'hr':'hour',
                       'hum':'humidity',
                       'cnt':'count'})
hour.head()
# Out:
#    instant      dteday season  year  ...  windspeed  casual  registered  count
# 0        1  2011-01-01      1     0  ...        0.0       3          13     16
# 1        2  2011-01-01      1     0  ...        0.0       8          32     40
# 2        3  2011-01-01      1     0  ...        0.0       5          27     32
# 3        4  2011-01-01      1     0  ...        0.0       3          10     13
# 4        5  2011-01-01      1     0  ...        0.0       0           1      1
#
# [5 rows x 17 columns]

# %%
hour_task2 = hour
hour = hour.drop(columns=['instant', 'dteday', 'year'])

# %%
cols = ['season','month','hour','holiday','weekday','workingday','weather']

for col in cols:
    hour[col] = hour[col].astype('category')
hour.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   season      17379 non-null  category
#  1   month       17379 non-null  category
#  2   hour        17379 non-null  category
#  3   holiday     17379 non-null  category
#  4   weekday     17379 non-null  category
#  5   workingday  17379 non-null  category
#  6   weather     17379 non-null  category
#  7   temp        17379 non-null  float64
#  8   atemp       17379 non-null  float64
#  9   humidity    17379 non-null  float64
#  10  windspeed   17379 non-null  float64
#  11  casual      17379 non-null  int64
#  12  registered  17379 non-null  int64
#  13  count       17379 non-null  int64
# dtypes: category(7), float64(4), int64(3)
# memory usage: 1.0 MB

# %%
# figure(figsize=(16, 14), dpi=80)
fig, ax = plt.subplots(1,2,figsize=(24,10))
sb.pointplot(data=hour, x='hour', y='registered', hue='weekday', ax=ax[0])
ax[0].set(title='Count of bikes during weekdays and weekends by Registered Customers')

sb.pointplot(data=hour, x='hour', y='casual', hue='weekday', ax=ax[1])
ax[1].set(title='Count of bikes during weekdays and weekends by Casual Customers')
# Out:
# [Text(0.5, 1.0, 'Count of bikes during weekdays and weekends by Casual Customers')]

# %% [markdown]
# From this pointplot,we can see that number of bike rent in working days starts to increase from 6 am in the morning.The hourly variation of the ridership shows that the peak timings patterns are strongly office commuter-oriented, with major peaks in the morning (7–9 am) and evening rushes (5–6 pm) by registered customers.That means this number increases at office or college starting time and leaving time.But from 9 am to 4 pm ,number of bike rent is normal.But in weekend days we can see major pick from noon to evening.Because at this time in weekend,people go out for recreation.
# But for casual users, we find quite different outcome.The casual users are more active in weekend during the afternoon and evening time, we can see peak around 5 pm.This could indicate the sight-seeing and city tours for the casual users.
#
# So we can see a clear difference using this two graphs how the registered and casual users are reacting in different timeframe.

# %%
fig, ax = plt.subplots(figsize=(15,10))
sb.pointplot(data=hour, x='hour', y='count', hue='weather', ax=ax)
ax.set(title='Count of bikes during different weathers')
# Out:
# [Text(0.5, 1.0, 'Count of bikes during different weathers')]

# %% [markdown]
# From this graph, we can see that users are more active in clear, few clouds or partly cloudy weather and pick time is around 8 am.We also find very few active users in bad weather like heavy rain,thunderstorm or ice pallets.

# %%
fig, ax = plt.subplots(figsize=(15,10))
sb.pointplot(data=hour, x='hour', y='count', hue='season', ax=ax)
ax.set(title='Count of bikes during different seasons')
# Out:
# [Text(0.5, 1.0, 'Count of bikes during different seasons')]

# %% [markdown]
# Here,We can observe that in spring season number of active users is highest and in winter season the number is lowest.

# %%
fig, ax = plt.subplots(1,2,figsize=(20,10))
sb.barplot(data=hour, x='month', y='registered', ax=ax[0],palette="Blues_d")
ax[0].set(title='Count of bikes during different months by registered users')

sb.barplot(data=hour, x='month', y='casual', ax=ax[1],palette="Blues_d")
ax[1].set(title='Count of bikes during different months by casual users')
# Out:
# [Text(0.5, 1.0, 'Count of bikes during different months by casual users')]

# %% [markdown]
# From this barplot , we can see that number of both active registered users and casual users increase gradually from January.This number decreases at the end of the year.But increase rate for casual users is little high than registered users.

# %%
fig, ax = plt.subplots(1,2,figsize=(20,10))
sb.barplot(data=hour, x='weekday', y='registered', ax=ax[0],palette="Blues_d")
ax[0].set(title='Count of bikes during different days by registered users')

sb.barplot(data=hour, x='weekday', y='casual', ax=ax[1],palette="Blues_d")
ax[1].set(title='Count of bikes during different days by casual users')
# Out:
# [Text(0.5, 1.0, 'Count of bikes during different days by casual users')]

# %%
from statsmodels.graphics.gofplots import qqplot
fig, (ax1,ax2) = plt.subplots(ncols=2, figsize=(20,6))
sb.distplot(hour['count'], ax=ax1)
ax1.set(title='Distribution of the users')
qqplot(hour['count'], ax=ax2, line='s')
ax2.set(title='Theoritical quantiles')
# Out:
# [Text(0.5, 1.0, 'Theoritical quantiles')]

# %%
def dist_plot(columns):
    for col in columns:
        plt.figure(figsize=(14,6))
        sb.distplot(x = hour[col])
        plt.show
dist_plot(['temp','casual', 'windspeed', 'humidity'])

# %%
hour.head()
# Out:
#    instant      dteday season  year  ... windspeed casual registered count
# 0        1  2011-01-01      1     0  ...       0.0      3         13    16
# 1        2  2011-01-01      1     0  ...       0.0      8         32    40
# 2        3  2011-01-01      1     0  ...       0.0      5         27    32
# 3        4  2011-01-01      1     0  ...       0.0      3         10    13
# 4        5  2011-01-01      1     0  ...       0.0      0          1     1
#
# [5 rows x 17 columns]

# %%
titl=['Boxplot of Temperature' , 'Boxplot of Windspeed','Boxplot of Humidity','Boxplot of Total Users']
def box_plot(columns):
  i=0
  for col in columns:
      plt.figure(figsize=(14,6))
      sb.boxplot(data = hour[col])
      plt.title(titl[i])
      i=i+1
      plt.show()
box_plot(['temp','windspeed', 'humidity','count'])

# %% [markdown]
# Boxplot of temperature indicates that the interquartile range is from 0.37 to 0.68 which means 25% to 75% data falls in range between 0.37 to 0.68 .
# In the same way,boxplot of humidity shows that interquartile range is between 0.45 to 0.79.

# %%
corr = hour.corr()
plt.figure(figsize=(15,10))
sb.heatmap(corr, annot=True, annot_kws={'size':18})

# %%
fig,ax = plt.subplots(figsize=(16,14))
sb.boxplot(data=hour[['count',
                          'hour']],x='hour',y='count',ax=ax)
ax.set(title="Checking for outliners in day hours")
# Out:
# [Text(0.5, 1.0, 'Checking for outliners in day hours')]

# %% [markdown]
# **4. Ask questions about the data which can be answered using the available data.**

# %% [markdown]
# ANS:
# Q1) Who (registered or casual) users are more active ?
#
# Q2) In which days registered users are more active ?
#
# Q3) In which days casual users are more active ?
#
# Q4) Which seasons are preferable to users to rent bikes ?
#
# Q5) In which weather conditions , users are more active ?
#
# Q6) In which year,number of bike rent is high?
#
# Q7) How humidity and windspeed effect users to rent bikes ?

# %% [markdown]
# **5. Find what kind of learning can be done on this dataset, what the features are and what the response is.**

# %% [markdown]
# Regression analysis can be done on this dataset.
#
# Features are year,temp,humidity,windspeed,holiday,weekday,workingday,weather and response is count .

# %% [markdown]
# **6. Find what model is suitable for this dataset and explain why.**

# %% [markdown]
# By testing the model's performance, cross validation score, residual analysis, MSE value, R squre value we found that among simple linear regression,multiple linear regression,ridge regression,polynomial regression; Ridge regression was the most suitable model for this dataset.Then Multiple linear regression comes in handy.

# %% [markdown]
# **7. Tell what feature(s) are significant for the learning purpose and explain why.**

# %% [markdown]
# Most significant feature is Hour.because from our previous graphs ,we find that hour is highly correlated with count. then next significance feature is temperature because the correlation between temp and count is 0.4 . the next feature is humidity which has -0.32 correlation with count variable and last significance feature is windspeed

# %% [markdown]
# **8. Separate training and testing data from the single dataset.**

# %%
# Defining categorical variables encoder method
def fit_transform_ohe(df,col_name):
    """This function performs one hot encoding for the specified
column.
    Args:
        df(pandas.DataFrame): the data frame containing the mentioned column name
        col_name: the column to be one hot encoded
    Returns:
        tuple: label_encoder, one_hot_encoder, transformed column as pandas Series
    """
    # label encode the column
    le = preprocessing.LabelEncoder()
    le_labels = le.fit_transform(df[col_name])
    df[col_name+'_label'] = le_labels
    # one hot encoding
    ohe = preprocessing.OneHotEncoder()
    feature_arr = ohe.fit_transform(df[[col_name+'_label']]).toarray()
    feature_labels = [col_name+'_'+str(cls_label) for cls_label in le.classes_]
    features_df = pd.DataFrame(feature_arr, columns=feature_labels)
    return le,ohe,features_df

# given label encoder and one hot encoder objects, 
# encode attribute to ohe
def transform_ohe(df,le,ohe,col_name):
    """This function performs one hot encoding for the specified
        column using the specified encoder objects.

    Args:
        df(pandas.DataFrame): the data frame containing the mentioned column name
        le(Label Encoder): the label encoder object used to fit label encoding
        ohe(One Hot Encoder): the onen hot encoder object used to fit one hot encoding
        col_name: the column to be one hot encoded

    Returns:
        tuple: transformed column as pandas Series

    """
    # label encode
    col_labels = le.transform(df[col_name])
    df[col_name+'_label'] = col_labels
    
    # ohe 
    feature_arr = ohe.fit_transform(df[[col_name+'_label']]).toarray()
    feature_labels = [col_name+'_'+str(cls_label) for cls_label in le.classes_]
    features_df = pd.DataFrame(feature_arr, columns=feature_labels)
    
    return features_df

# %%
hour_dataset = pd.read_csv("hour.csv")
# Renaming columns names to more readable names
hour_dataset.rename(columns={'instant':'rec_id',
                        'dteday':'datetime',
                        'holiday':'is_holiday',
                        'workingday':'is_workingday',
                        'weathersit':'weather_condition',
                        'hum':'humidity',
                        'mnth':'month',
                        'cnt':'total_count',
                        'hr':'hour',
                        'yr':'year'},inplace=True)

###########################
# Setting proper data types
###########################
# date time conversion
hour_dataset['datetime'] = pd.to_datetime(hour_dataset.datetime)

# categorical variables
hour_dataset['season'] = hour_dataset.season.astype('category')
hour_dataset['is_holiday'] = hour_dataset.is_holiday.astype('category')
hour_dataset['weekday'] = hour_dataset.weekday.astype('category')
hour_dataset['weather_condition'] = hour_dataset.weather_condition.astype('category')
hour_dataset['is_workingday'] = hour_dataset.is_workingday.astype('category')
hour_dataset['month'] = hour_dataset.month.astype('category')
hour_dataset['year'] = hour_dataset.year.astype('category')
hour_dataset['hour'] = hour_dataset.hour.astype('category')

# %%
# Divide the dataset into training and testing sets
X, X_test, y, y_test = train_test_split(hour_dataset.iloc[:,0:-3],
                                        hour_dataset.iloc[:,-1],
                                        test_size=0.33,
                                        random_state=42)
X.reset_index(inplace=True)
y = y.reset_index()

X_test.reset_index(inplace=True)
y_test = y_test.reset_index()

# %%
# Encoding all the categorical features
cat_attr_list = ['season','is_holiday',
                 'weather_condition','is_workingday',
                 'hour','weekday','month','year']
# though we have transformed all categoricals into their one-hot encodings, note that ordinal
# attributes such as hour, weekday, and so on do not require such encoding.
numeric_feature_cols = ['temp','humidity','windspeed',
                        'hour','weekday','month','year']
subset_cat_features =  ['season','is_holiday','weather_condition','is_workingday']

###############
# Train dataset
###############
encoded_attr_list = []
for col in cat_attr_list:
    return_obj = fit_transform_ohe(X,col)
    encoded_attr_list.append({'label_enc':return_obj[0],
                              'ohe_enc':return_obj[1],
                              'feature_df':return_obj[2],
                              'col_name':col})


feature_df_list  = [X[numeric_feature_cols]]
feature_df_list.extend([enc['feature_df'] \
                        for enc in encoded_attr_list \
                        if enc['col_name'] in subset_cat_features])

train_df_new = pd.concat(feature_df_list, axis=1)
print("Train dataset shape::{}".format(train_df_new.shape))
print(train_df_new.head())

##############
# Test dataset
##############
test_encoded_attr_list = []
for enc in encoded_attr_list:
    col_name = enc['col_name']
    le = enc['label_enc']
    ohe = enc['ohe_enc']
    test_encoded_attr_list.append({'feature_df':transform_ohe(X_test,
                                                              le,ohe,
                                                              col_name),
                                   'col_name':col_name})
    
    
test_feature_df_list = [X_test[numeric_feature_cols]]
test_feature_df_list.extend([enc['feature_df'] \
                             for enc in test_encoded_attr_list \
                             if enc['col_name'] in subset_cat_features])

test_df_new = pd.concat(test_feature_df_list, axis=1) 
print("Test dataset shape::{}".format(test_df_new.shape))
print(test_df_new.head())
# Out:
# Train dataset shape::(11643, 19)
#    temp  humidity  ...  is_workingday_0 is_workingday_1
# 0  0.64      0.65  ...              0.0             1.0
# 1  0.50      0.45  ...              0.0             1.0
# 2  0.86      0.47  ...              1.0             0.0
# 3  0.30      0.61  ...              0.0             1.0
# 4  0.54      0.19  ...              1.0             0.0
#
# [5 rows x 19 columns]
# Test dataset shape::(5736, 19)
#    temp  humidity  ...  is_workingday_0 is_workingday_1
# 0  0.80      0.27  ...              1.0             0.0
# 1  0.24      0.41  ...              1.0             0.0
# 2  0.32      0.66  ...              0.0             1.0
# 3  0.78      0.52  ...              0.0             1.0
# 4  0.26      0.56  ...              0.0             1.0
#
# [5 rows x 19 columns]

# %%
X = train_df_new
y = y.total_count.values.reshape(-1,1)

lin_reg = linear_model.LinearRegression()

# using the k-fold cross validation (specifically 10-fold) to reduce overfitting affects
# cross_val_predict function returns cross validated prediction values as fitted by the model object.
predicted = cross_val_predict(lin_reg, X, y, cv=10)

# %%
# Analysing residuals in our predictinos
fig,ax = plt.subplots(figsize=(15,15))
ax.scatter(y, y-predicted)
ax.axhline(lw=2,color='black')
ax.set_xlabel('Observed')
ax.set_ylabel('Residual')
ax.set_title('Residual Plot')
plt.show()

# %%
# Evaluating model in cross-validation iteration

r2_scores = cross_val_score(lin_reg, X, y, cv=10)
mse = cross_val_score(lin_reg, X, y, cv=10,scoring='neg_mean_squared_error')

fig,ax = plt.subplots(figsize=(16,14))
ax.plot(range(0,10),
        r2_scores)
ax.set_xlabel('Iteration')
ax.set_ylabel('R.Squared')
ax.set_title('Cross-Validation scores')
plt.show()


print("R-squared::{}".format(r2_scores))
print("MSE::{}".format(mse))
# Out:
# R-squared::[0.39894459 0.35575732 0.3873037  0.38796861 0.42489499 0.41571164
#  0.37379762 0.39339864 0.39589746 0.40871611]
# MSE::[-19612.38349313 -20800.77110185 -20256.54013607 -18545.99033804
#  -18746.57816436 -21015.35560028 -21549.12876053 -21567.27946203
#  -21044.42416385 -18899.05989574]

# %%
hour['count'] = np.log(hour['count'])

# %% [markdown]
# # **TASK 3**

# %% [markdown]
# **1. Describe the question in plain language**

# %% [markdown]
# Apart from interesting real world applications of bike sharing systems, the characteristics of data being generated by these systems make them attractive for the research. Opposed to other transport services such as bus or subway, the duration of travel, departure and arrival position is explicitly recorded in these systems. This feature turns bike sharing system into a virtual sensor network that can be used for sensing mobility in the city. Hence, it is expected that most of important events in the city could be detected via monitoring these data.The goal of this question is to extract these information from the dataset

# %% [markdown]
# **2. Split the dataset into train and test set using library/own methods.**

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %% [markdown]
# **3. Fit the following model(s)(any 3) to the data (where appropriate):**
# - Simple Linear Regression
# - Multiple Linear Regression
# - Polynomial Regression
# - Lasso/Ridge Regression
# - Support Vector Regression(using Kernels)

# %% [markdown]
# **Model choose using Cross Validation:**

# %%
pd.get_dummies(hour['season'], prefix='season', drop_first=True)
# Out:
#        season_2  season_3  season_4
# 0             0         0         0
# 1             0         0         0
# 2             0         0         0
# 3             0         0         0
# 4             0         0         0
# ...         ...       ...       ...
# 17374         0         0         0
# 17375         0         0         0
# 17376         0         0         0
# 17377         0         0         0
# 17378         0         0         0
#
# [17379 rows x 3 columns]

# %%
df_oh = hour

def one_hot_encoding(data, column):
    data = pd.concat([data, pd.get_dummies(data[column], prefix=column, drop_first=True)], axis=1)
    data = data.drop([column], axis=1)
    return data

cols = ['season','month','hour','holiday','weekday','workingday','weather']

for col in cols:
    df_oh = one_hot_encoding(df_oh, col)
df_oh.head()
# Out:
#    temp   atemp  humidity  ...  weather_2  weather_3  weather_4
# 0  0.24  0.2879      0.81  ...          0          0          0
# 1  0.22  0.2727      0.80  ...          0          0          0
# 2  0.22  0.2727      0.80  ...          0          0          0
# 3  0.24  0.2879      0.75  ...          0          0          0
# 4  0.24  0.2879      0.75  ...          0          0          0
#
# [5 rows x 55 columns]

# %%
X = df_oh.drop(columns=['atemp', 'windspeed', 'casual', 'registered', 'count'], axis=1)
y = df_oh['count']

# %%
from sklearn.linear_model import LinearRegression, Ridge, HuberRegressor, ElasticNetCV,Lasso
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, ExtraTreesRegressor

models = [LinearRegression(),
         Ridge(),
         Lasso(),
         HuberRegressor(),
         ElasticNetCV(),
         DecisionTreeRegressor(),
         RandomForestRegressor()]

# %%
from sklearn.model_selection import KFold,cross_val_score
def train(model):
    kfold = KFold(n_splits=5,shuffle=True, random_state=42)
    pred = cross_val_score(model, X, y, cv=kfold, scoring='neg_mean_squared_error')
    cv_score = pred.mean()
    print('Model:',model)
    print('CV score:', abs(cv_score))

# %%
for model in models:
  train(model)
# Out:
# Model: LinearRegression()
# CV score: 0.44848294171385605
# Model: Ridge()
# CV score: 0.4484090089563206
# Model: Lasso()
# CV score: 2.2086834089905567
# Model: HuberRegressor()
# CV score: 0.4659680438087975
# Model: ElasticNetCV()
# CV score: 0.4561491813535915
# Model: DecisionTreeRegressor()
# CV score: 0.4357853064178224
# Model: RandomForestRegressor()
# CV score: 0.23259566729992004

# %% [markdown]
# **Multiple Linear Regression:**

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
regr = LinearRegression()
regr.fit(x_train,y_train)
print(regr.score(x_test, y_test))
# Out:
# 0.7925166607901197

# %%
from sklearn.metrics import r2_score,mean_squared_error


y_pred = regr.predict(x_test)
r2_score(y_test,y_pred)
mean_squared_error(y_test,y_pred)
# Out:
# 0.45137441700958747

# %%
hour2 = hour
import statsmodels.formula.api as sm
X_train, X_test, y_train, y_test = train_test_split(hour2,hour2['count'], test_size=0.2)
model_fit = sm.ols(formula="count ~ hour + season + month + weather + temp +windspeed", data=X_train).fit()
print(model_fit.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  count   R-squared:                       0.797
# Model:                            OLS   Adj. R-squared:                  0.797
# Method:                 Least Squares   F-statistic:                     1299.
# Date:                Tue, 11 Jan 2022   Prob (F-statistic):               0.00
# Time:                        04:48:28   Log-Likelihood:                -14139.
# No. Observations:               13903   AIC:                         2.836e+04
# Df Residuals:                   13860   BIC:                         2.869e+04
# Df Model:                          42
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept        2.6517      0.038     69.618      0.000       2.577       2.726
# ...

# %% [markdown]
# **Simple Linear Regression**

# %%
x_simpleLinear = np.array(df_oh['temp']).reshape(-1,1)
y_simpleLinear = np.array(df_oh['count']).reshape(-1,1)

X_train_s, X_test_s, y_train_s, y_test_s = train_test_split(x_simpleLinear, y_simpleLinear, test_size = 0.25)

regr = LinearRegression()
regr.fit(X_train_s,y_train_s)
print(regr.score(X_test_s, y_test_s))
# Out:
# 0.1565775491007062

# %%
y_pred = regr.predict(X_test_s)
plt.scatter(X_test_s, y_test_s, color ='b')
plt.plot(X_test_s, y_pred, color ='k')
  
plt.show()

# %% [markdown]
# **Ridge Regression**

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)
rr = Ridge(alpha=0.01)
rr.fit(x_train, y_train) 
pred_train_rr= rr.predict(x_train)
print(np.sqrt(mean_squared_error(y_train,pred_train_rr)))
print(r2_score(y_train, pred_train_rr))

pred_test_rr= rr.predict(x_test)
print(np.sqrt(mean_squared_error(y_test,pred_test_rr))) 
print(r2_score(y_test, pred_test_rr))
# Out:
# 0.6662400863177035
# 0.8000082029145635
# 0.6713259722088666
# 0.7928365250333838

# %% [markdown]
# **Polynomial Regression:**

# %%
import math as m
# %matplotlib inline
dff = pd.read_csv("hour.csv")
dff["DateTime"]=dff[['dteday','hr']].apply(lambda x:x['dteday']+" "+str(x["hr"])+":00",axis=1)

def zero_pad_hour(s):
    if len(str(s))==2:
        return str(s)
    else:
        return "0"+str(s)
dff["DateTime"]=dff[['dteday','hr']].apply(lambda x:x['dteday']+\
                                         " "+zero_pad_hour(x["hr"])+":00",axis=1)
dff["DateTime"]=pd.to_datetime(dff.DateTime,format="%Y-%m-%d %H:%M")    

count=dff.cnt
count.index=dff.DateTime
plt.figure(figsize=(12,5))
plt.plot(count[:24*7])

dff.weathersit=dff.weathersit.astype(str)

from scipy.stats import pearsonr
print(pearsonr(dff.temp,dff.atemp))
sb.lmplot(x='temp',y='atemp',data=dff,hue='season',fit_reg=False)
# Out:
# (0.9876721390396483, 0.0)

# %%
X=dff[['season', 'yr', 'mnth', 'hr', \
      'workingday','weathersit', 'temp','hum', 'windspeed']].copy()
y=dff.registered

X["DayNight"]=X.hr.map(lambda x: 0 if x<7 else 1)

def peakhour(x):
    if x in [7,8,16,17,18,19]:
        return 1
    else:
        return 0
X["PeakHours"]=X.hr.map(lambda x: peakhour(x))

dummy=pd.get_dummies(X.weathersit,prefix="WeatherSit")
#join the dummy to dataframe
X=X.join(dummy)
#drop weather sit col
X=X.drop(['weathersit'],axis=1)

from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(X,y)
y_hat=lr.predict(X)
print("R sq",r2_score(y,y_hat))
print("MAE",mean_absolute_error(y,y_hat))
print("MSE",mean_squared_error(y,y_hat))
print("RMSE",mean_squared_error(y,y_hat)**0.5)
# Out:
# R sq 0.6026021202792493
# MAE 70.23538539781535
# MSE 9103.475302620154
# RMSE 95.41213393809068

# %%
residuals=y-y_hat
sum(residuals)
# Out:
# -5.417462034529308e-10

# %%
#residulas plot should be normal
sb.distplot(residuals)

# %%
#graph should follow homoskdacity, here it is hetroskadacity
plt.scatter(y_hat,residuals)
plt.hlines(y=0,xmin=-100,xmax=500,colors='r')

# %%
print(dff['registered'].skew()) #skewness is more , we can log transform this column
sb.distplot(dff['registered'])
# Out:
# 1.5579042256481028

# %%
#log Normal
log_y=np.log1p(y)
model=LinearRegression()
model.fit(X,log_y)
model.score(X,log_y)
print("R sq",r2_score(y,y_hat))
print("MAE",mean_absolute_error(y,y_hat))
print("MSE",mean_squared_error(y,y_hat))
print("RMSE",mean_squared_error(y,y_hat)**0.5)
# Out:
# R sq 0.6026021202792493
# MAE 70.23538539781535
# MSE 9103.475302620154
# RMSE 95.41213393809068

# %%
#Non Linear Model
from sklearn.preprocessing import PolynomialFeatures
poly=PolynomialFeatures(degree=4,include_bias=False)
X_poly=poly.fit_transform(X)
model=LinearRegression(n_jobs=-1)
model.fit(X_poly,log_y)
model.score(X_poly,log_y)
y_hat=np.exp(model.predict(X_poly))
r2_score(y,y_hat)
# Out:
# 0.8820941926569354

# %%
plt.plot(y[:150],color='b')
plt.plot(y_hat[:150],color='r')

# %% [markdown]
# **4. Describe each model in plain language.**

# %% [markdown]
# ***Simple Linear Regression:***
# is a statistical method that allows us to summarize and study relationships between two continuous (quantitative) variables:
# One variable, denoted x, is regarded as the predictor, explanatory, or independent variable.
# The other variable, denoted y, is regarded as the response, outcome, or dependent variable.
#
# ***Multiple Linear Regression:***
# Multiple linear regression refers to a statistical technique that is used to predict the outcome of a variable based on the value of two or more variables. It is sometimes known simply as multiple regression, and it is an extension of linear regression. The variable that we want to predict is known as the dependent variable, while the variables we use to predict the value of the dependent variable are known as independent or explanatory variables.
#
# ***Ridge Regression:***
# Ridge regression is a model tuning method that is used to analyse any data that suffers from multicollinearity. This method performs L2 regularization. When the issue of multicollinearity occurs, least-squares are unbiased, and variances are large, this results in predicted values being far away from the actual values.

# %% [markdown]
# **5. Compute the loss.**

# %% [markdown]
# From previous computation:
#
# ***simple linear regression:***
#
# R-squared : 0.1565775491007062
#
# ***Multiple Linear Regression:***
#
# R-squared value : 0.7925166607901197
#
# ***Ridge Regression:***
#
# R-squared value : 0.7928365250333838 .
#
# ***Polynomial regression:***
# R-squared value: 0.60

# %% [markdown]
# **6. Test the model(s) on test data.**

# %%
y_pred = regr.predict(X_test_s)
plt.scatter(X_test_s, y_test_s, color ='b')
plt.plot(X_test_s, y_pred, color ='k')
  
plt.show()

# %% [markdown]
# **7. Interpret the result in plain language (Can you tell the story?)**

# %% [markdown]
# We found that the number of active users of Bike sharing depends on the hour ,week days,weather and the temperature. Also, it seems that there is an interaction between variables, like hour and day of week, or month and year etc and for that reason, the tree-based models like Gradient Boost and Random Forest performed much better than the linear regression. Moreover, the tree-based models are able to capture nonlinear relationships, so for example, the hours and the temperature do not have a linear relationship, so for example, if it is extremely hot or cold then the bike rentals can drop. Our model has an RMSE of 42 in the test dataset which seems to be promising.
#
#
#
# The age group that uses the city bike rental the most is Gen X with an age range of 40–55 years. And the gender that uses the Citybike rental the most is men.
#
#
# The highest total daily borrowing of bicycles is Thursday with a total of 3,076 transactions and the most daily borrowing times today are 08 AM, 04 PM, and 06 PM. Then in second place for the most total daily bicycle borrowings is Friday with a total of 950 transactions and the most daily borrowing time today is 08 AM. Finally, for the most daily total borrowed bicycles, the next is Tuesday with a total of 924 transactions and the most daily borrowing time today is 08 AM.
#
#
# The day that has the most bicycles borrowed is Thursday with a total of 8,470 transactions.
# The 5 favorite departure stations for borrowing bicycles and favorite times are:
# i.) Grove St PATH with favorite times for borrowing bicycles is 05 AM, 06 AM, 07 PM and 08 PM.
# ii.) Hamilton Park with favorite time to rent bicycles is 08 AM.
# iii.) Columbus Dr at Exchange P1 with favorite time to rent a bike is 5 PM.
# iv.) Sip Ave with favorite time to borrow bicycles is 06 PM.
# v.) Newport PATH favorite time to rent bikes is 05 PM.
#
#
# The user’s age does not affect the duration of the bicycle borrowing (trip duration by the minute), and vice versa. Because the results of the visualization above do not show a pattern of relationship between User Age and Borrowing Time. Although the Mean Absolute Error (MAE) value obtained from the model made is 4 minutes from the time value of the original data.

# %% [markdown]
# **8. Evaluate different metrics for judging a model (MSE/R-square/CI/P-value/F-value/AIC/BIC etc.)**

# %% [markdown]
# ***simple linear regression:***
#
# R-squared : 0.1565775491007062
#
# ***Multiple Linear Regression:***
#
# R-squared value : 0.7925166607901197
#
# AIC  : 2.836e+04
#
# BIC  : 2.869e+04
#
# ***Ridge Regression:***
#
# R-squared value : 0.7928365250333838 .
#
# ***Polynomial regression:***
# R-squared value: 0.60

# %% [markdown]
# **9. Interpret significance of the predictors.**

# %% [markdown]
# Most significance predictor is Hour.because from our previous graphs ,we find that hour is highly correlated with count.
# then next significance predictor is temperature because the correlation between temp and count is 0.4 .
# the next predictor is humidity which has -0.32 correlation with count variable and last significance predictor is windspeed

# %% [markdown]
# **10. Compare between models, i.e. tell which model performs best.**
#
# From previous analysis:
#
# Model: LinearRegression()
# CV score: 0.44848294171385605
# Model: Ridge()
# CV score: 0.4484090089563206
# Model: Lasso()
# CV score: 2.2086834089905567
# Model: HuberRegressor()
# CV score: 0.4659680438087975
# Model: ElasticNetCV()
# CV score: 0.4561491813535915
# Model: DecisionTreeRegressor()
# CV score: 0.4357853064178224
# Model: RandomForestRegressor()
# CV score: 0.23259566729992004

# %% [markdown]
# **11. Choose between models (which one is best suited to answer your question?)**
#
# R-squared for simple linear regression : 0.1565775491007062
#
# this means that our model is not good enough with only one feature variable.
#
# R squared value for polynomial regression is 0.60 which is better than simple linear regression.
#
# R-squared value of Multiple Linear Regression : 0.7925166607901197
#
# AIC for multiple linear regression : 2.836e+04
#
# BIC for multiple linear regression : 2.869e+04
#
# so these values interprets that multiple linear regression model is better than simple linear regression model.
#
# R-squared value for Ridge Regression : 0.7928365250333838 .
# This value indicates that Ridge Regression is quite better than multiple linear regression model and far better than simple linear regression model.

# %% [markdown]
# **12. Draw conclusions from different analyses.**

# %% [markdown]
# From our analysis,We can observe that the number of Bike Rentals depends on the hour and the temperature. Also, it seems that there is an interaction between variables, like hour and day of week, or month and year etc and for that reason, the tree-based models like Gradient Boost and Random Forest performed much better than the linear regression. Moreover, the tree-based models are able to capture nonlinear relationships, so for example, the hours and the temperature do not have a linear relationship, so for example, if it is extremely hot or cold then the bike rentals can drop. Our model has an RMSE of 42 in the test dataset which seems to be promising.
# We also perform simple linear regression,multiple linear regression , polynomial regression and ridge regression.And we found than riidge regression performs better
